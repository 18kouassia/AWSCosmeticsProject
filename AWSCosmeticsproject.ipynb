# %% [markdown]
# For this project I will be loading a csv file into AWS using various AWS services. My goal is to load it where the data can be queried and used.

# %% [markdown]
# ##### I created a bucket in s3 for the project

# %% [markdown]
# ![image.png](attachment:28704bfd-1f9e-4e14-82b5-c29de2a80a3c.png)

# %% [markdown]
# ##### I created a staging folder where I will initially load the data, and a datawarehouse where I will load the final data through AWS glue

# %% [markdown]
# ![image.png](attachment:f6a3308c-468d-4e67-a447-1f8b1a6ad281.png)

# %% [markdown]
# ![image.png](attachment:6a149417-3bc3-461b-8f5c-9087eb334a97.png)

# %% [markdown]
# ##### I created a bucket for the data that I will be importing into glue. If I was going to use data from multiple sources and join them, I would do that at this stage

# %% [markdown]
# ![image.png](attachment:d80ed39b-2975-4b27-aedf-f590d4340e3f.png)

# %% [markdown]
# ##### I attached a destination bucket, the datawarehouse bucket that I had created in s3, to the source bucket

# %% [markdown]
# ![image.png](attachment:50965720-de3d-4ef7-9ddb-89c77bde2e37.png)

# %% [markdown]
# ##### I succesfully ran the job to load the data into the datawarehouse

# %% [markdown]
# ![image.png](attachment:74bde7ad-27cf-4a8b-b46a-c9b94ce86334.png)

# %% [markdown]
# ![image.png](attachment:4e5bbd8f-32f7-4286-a55e-50eff0284e94.png)

# %% [markdown]
# ##### I created a crawler to load my data from the datawarehouse in s3 to the glue database

# %% [markdown]
# ![image.png](attachment:f42896c8-ee9b-42d4-99b3-e0bad10848cc.png)

# %% [markdown]
# ![image.png](attachment:42fa3b69-e30e-4c43-ba9a-1c876c03b15a.png)

# %% [markdown]
# ##### The data is available in Athena to query

# %% [markdown]
# ![image.png](attachment:aab4aed8-1481-4eb8-9ff0-1504daff1cbb.png)
